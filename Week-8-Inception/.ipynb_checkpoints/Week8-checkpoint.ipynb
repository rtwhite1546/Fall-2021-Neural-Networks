# %% [markdown]
# # Week 8
#
# This week, we consider Inception nets (Szegedy, et al., 2014 https://arxiv.org/abs/1409.4842), which are CNNs with so-called inception modules, which are small groupings of parallel convolutional layers that act on the same input feature map, processes it through different means, and concatenates the results. In particular, it uses convolutional layers with different-sized filters (1x1, 3x3, and 5x5 in Inception-v1), which are adept at finding patterns at different scales.
#
# In this notebook, we implement a small version of Inception and test it on the CIFAR-10 dataset.

# %% [markdown]
# ## GPU Computing
#
# CNNs especially benefit from parallelization within GPUs. Only NVIDIA video cards are currently compatible, which can be in your local device or in a cloud. The following code can check if tensorflow sees a GPU

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib

numGPUs = len(tf.config.experimental.list_physical_devices('GPU'))

print('Num GPUs Available: ', numGPUs)

if numGPUs > 0:
    print(tf.test.gpu_device_name())
    print(device_lib.list_local_devices()[1].physical_device_desc)
# Out:
# Num GPUs Available:  1
# /device:GPU:0
# device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:2d:00.0, compute capability: 8.6

# %% [markdown]
# ## MiniGoogLeNet
#
# Note for GoogLeNet, the inception modules are not exactly sequential, so we will need to define layers a little differently as we see below, after importing some packages. And, we use "miniception" modules as per *Understanding Deep Learning Requires Re-Thinking Generalization* (Zhang, et al., 2017 http://arxiv.org/abs/1611.03530), which work well for small-dimensional image datasets.

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import add
from tensorflow.keras.utils import to_categorical

import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
class MiniGoogLeNet:
    def convolution_module(x, K, kX, kY, stride, channelsDim, padding="same"):
        # create a CONV -> BN -> RELU sequence
        x = Conv2D(K, (kX, kY), strides = stride, padding = padding)(x)
        x = BatchNormalization(axis = channelsDim)(x)
        x = Activation('relu')(x)
        
        # return the output
        return x
    
    def inception_module(x, numberOf1x1Kernels, numberOf3x3Kernels, channelsDim):
        # define two "parallel" convolutions of size 1x1 and 3x3 concatenated across the channels dimension
        convolution_1x1 = MiniGoogLeNet.convolution_module(x, numberOf1x1Kernels, 1, 1, (1, 1), channelsDim)
        convolution_3x3 = MiniGoogLeNet.convolution_module(x, numberOf3x3Kernels, 3, 3, (1, 1), channelsDim)
        x = concatenate([convolution_1x1, convolution_3x3], axis = channelsDim)
        
        return x
        
    def downsample_module(x, K, channelsDim):
        # define a CONV and POOL and then concatenate across the channels dimension
        convolution_3x3 = MiniGoogLeNet.convolution_module(x, K, 3, 3, (2, 2), channelsDim, padding = 'valid')
        pool = MaxPooling2D((3, 3), strides = (2, 2))(x)
        x = concatenate([convolution_3x3, pool], axis = channelsDim)
        
        return x
    
    def build(width, height, depth, classes):
        inputShape = (height, width, depth)
        channelsDim = -1
        
        if backend.image_data_format() == "channels_first":
            inputShape = (depth, height, width)
            channelsDim = 1
        
        # define the model input and first CONV module
        inputs = Input(shape = inputShape)
        x = MiniGoogLeNet.convolution_module(inputs, 96, 3, 3, (1, 1), channelsDim)
        
        # two inception modules followed by a downsample module
        x = MiniGoogLeNet.inception_module(x, 32, 32, channelsDim)
        x = MiniGoogLeNet.inception_module(x, 32, 48, channelsDim)
        x = MiniGoogLeNet.downsample_module(x, 80, channelsDim)
        
        # four inception modules followed by a downsample module
        x = MiniGoogLeNet.inception_module(x, 112, 48, channelsDim)
        x = MiniGoogLeNet.inception_module(x, 96, 64, channelsDim)
        x = MiniGoogLeNet.inception_module(x, 80, 80, channelsDim)
        x = MiniGoogLeNet.inception_module(x, 48, 96, channelsDim)
        x = MiniGoogLeNet.downsample_module(x, 96, channelsDim)
        
        # two inception modules followed by global POOL and dropout
        x = MiniGoogLeNet.inception_module(x, 176, 160, channelsDim)
        x = MiniGoogLeNet.inception_module(x, 176, 160, channelsDim)
        x = AveragePooling2D((7, 7))(x)
        x = Dropout(0.5)(x)
        
        # softmax classifier
        x = Flatten()(x)
        x = Dense(classes)(x)
        x = Activation('softmax')(x)
        
        # create a model
        model = Model(inputs, x, name='MiniGoogLeNet')
        
        # return the model
        return model

# %% [markdown]
# ### MiniGoogLeNet on CIFAR-10
#
# Let's test it on CIFAR-10

# %%
# import the necessary packages
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.datasets import cifar10
import numpy as np
import os

from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %%
numberOfEpochs = 70
initialLearningRate = 0.005

def polynomial_decay(epoch):
    maxEpochs = numberOfEpochs
    baseLearningRate = initialLearningRate
    power = 1.0
    
    alpha = baseLearningRate * (1 - (epoch / float(numberOfEpochs))) ** power
    
    # return the learning rate
    return alpha
    
# load cifar10 data
((trainX, trainY), (testX, testY)) = cifar10.load_data()
trainX = trainX.astype('float')
testX = testX.astype('float')

# use mean subtraction
mean = np.mean(trainX, axis = 0)
trainX -= mean
testX -= mean

# convert labels to one-hot
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

callbacks = [LearningRateScheduler(polynomial_decay)]

print('[INFO] compiling model...')
opt = SGD(learning_rate = initialLearningRate, momentum=0.9)
model = MiniGoogLeNet.build(width = 32, height = 32, depth = 3, classes = 10)
model.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics=["accuracy"])

# print a model summary
#print(model.summary())

# train the network
print("[INFO] training network...")
H = model.fit(trainX, trainY, validation_data = (testX, testY), batch_size = 64, epochs = numberOfEpochs,
              callbacks = callbacks, verbose = 1)

# save the network to disk
#print("[INFO] serializing network...")
#model.save('output/MiniGoogLeNet_cifar10.hdf5')

# print a classification report
print('\n Test accuracy')
predictedY = model.predict(testX)
predictedY = predictedY.argmax(axis=1)
testY = testY.argmax(axis=1)
print(classification_report(testY, predictedY, digits=4))

# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, numberOfEpochs), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, numberOfEpochs), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, numberOfEpochs), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, numberOfEpochs), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
# Out:
# [INFO] compiling model...
# [INFO] training network...
# Epoch 1/70
# 782/782 [==============================] - 18s 22ms/step - loss: 1.4005 - accuracy: 0.4914 - val_loss: 1.0960 - val_accuracy: 0.6037
# Epoch 2/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.9681 - accuracy: 0.6576 - val_loss: 0.9037 - val_accuracy: 0.6841
# Epoch 3/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.7853 - accuracy: 0.7258 - val_loss: 0.9517 - val_accuracy: 0.6739
# Epoch 4/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.6575 - accuracy: 0.7711 - val_loss: 0.7985 - val_accuracy: 0.7282
# Epoch 5/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.5596 - accuracy: 0.8065 - val_loss: 0.9606 - val_accuracy: 0.6872
# Epoch 6/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4847 - accuracy: 0.8332 - val_loss: 0.9856 - val_accuracy: 0.6922
# Epoch 7/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.4243 - accuracy: 0.8522 - val_loss: 0.9931 - val_accuracy: 0.6876
# Epoch 8/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.3616 - accuracy: 0.8759 - val_loss: 0.7491 - val_accuracy: 0.7616
# Epoch 9/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.3048 - accuracy: 0.8942 - val_loss: 0.7826 - val_accuracy: 0.7610
# Epoch 10/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.2518 - accuracy: 0.9139 - val_loss: 0.9790 - val_accuracy: 0.7222
# Epoch 11/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.2111 - accuracy: 0.9286 - val_loss: 0.9633 - val_accuracy: 0.7439
# Epoch 12/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.1795 - accuracy: 0.9396 - val_loss: 0.9933 - val_accuracy: 0.7212
# Epoch 13/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.1429 - accuracy: 0.9529 - val_loss: 0.7248 - val_accuracy: 0.7834
# Epoch 14/70
# 782/782 [==============================] - 16s 21ms/step - loss: 0.1212 - accuracy: 0.9590 - val_loss: 1.0098 - val_accuracy: 0.7494
# Epoch 15/70
# 782/782 [==============================] - 16s 21ms/step - loss: 0.0996 - accuracy: 0.9665 - val_loss: 1.0864 - val_accuracy: 0.7571
# Epoch 16/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0781 - accuracy: 0.9752 - val_loss: 0.8768 - val_accuracy: 0.7913
# Epoch 17/70
# 782/782 [==============================] - 16s 21ms/step - loss: 0.0642 - accuracy: 0.9800 - val_loss: 0.8597 - val_accuracy: 0.7820
# Epoch 18/70
# 782/782 [==============================] - 16s 21ms/step - loss: 0.0529 - accuracy: 0.9836 - val_loss: 0.9867 - val_accuracy: 0.7726
# Epoch 19/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0425 - accuracy: 0.9875 - val_loss: 0.8314 - val_accuracy: 0.7988
# Epoch 20/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0340 - accuracy: 0.9902 - val_loss: 0.8389 - val_accuracy: 0.8058
# Epoch 21/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0299 - accuracy: 0.9917 - val_loss: 0.7552 - val_accuracy: 0.8177
# Epoch 22/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0269 - accuracy: 0.9926 - val_loss: 0.9383 - val_accuracy: 0.8015
# Epoch 23/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0212 - accuracy: 0.9944 - val_loss: 0.6775 - val_accuracy: 0.8352
# Epoch 24/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0182 - accuracy: 0.9951 - val_loss: 0.8792 - val_accuracy: 0.8065
# Epoch 25/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0135 - accuracy: 0.9970 - val_loss: 0.9526 - val_accuracy: 0.7988
# Epoch 26/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0100 - accuracy: 0.9983 - val_loss: 0.6727 - val_accuracy: 0.8438
# Epoch 27/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0087 - accuracy: 0.9984 - val_loss: 0.7069 - val_accuracy: 0.8387
# Epoch 28/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0083 - accuracy: 0.9984 - val_loss: 0.8141 - val_accuracy: 0.8285
# Epoch 29/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0066 - accuracy: 0.9987 - val_loss: 0.6958 - val_accuracy: 0.8427
# Epoch 30/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0066 - accuracy: 0.9989 - val_loss: 0.7056 - val_accuracy: 0.8390
# Epoch 31/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0064 - accuracy: 0.9988 - val_loss: 0.7008 - val_accuracy: 0.8385
# Epoch 32/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0049 - accuracy: 0.9993 - val_loss: 0.7111 - val_accuracy: 0.8389
# Epoch 33/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.7995 - val_accuracy: 0.8215
# Epoch 34/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0052 - accuracy: 0.9992 - val_loss: 0.7117 - val_accuracy: 0.8372
# Epoch 35/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 0.6763 - val_accuracy: 0.8517
# Epoch 36/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.6951 - val_accuracy: 0.8459
# Epoch 37/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.7021 - val_accuracy: 0.8469
# Epoch 38/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.6774 - val_accuracy: 0.8461
# Epoch 39/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.6673 - val_accuracy: 0.8487
# Epoch 40/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.6464 - val_accuracy: 0.8535
# Epoch 41/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.6744 - val_accuracy: 0.8507
# Epoch 42/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.6915 - val_accuracy: 0.8467
# Epoch 43/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.6879 - val_accuracy: 0.8472
# Epoch 44/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.6634 - val_accuracy: 0.8538
# Epoch 45/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.6668 - val_accuracy: 0.8525
# Epoch 46/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.6531 - val_accuracy: 0.8538
# Epoch 47/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.6608 - val_accuracy: 0.8518
# Epoch 48/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.6635 - val_accuracy: 0.8533
# Epoch 49/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6517 - val_accuracy: 0.8508
# Epoch 50/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.6621 - val_accuracy: 0.8499
# Epoch 51/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6529 - val_accuracy: 0.8573
# Epoch 52/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.6552 - val_accuracy: 0.8538
# Epoch 53/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6565 - val_accuracy: 0.8539
# Epoch 54/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.6576 - val_accuracy: 0.8545
# Epoch 55/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.6638 - val_accuracy: 0.8549
# Epoch 56/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6602 - val_accuracy: 0.8537
# Epoch 57/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6629 - val_accuracy: 0.8542
# Epoch 58/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.6599 - val_accuracy: 0.8542
# Epoch 59/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.6603 - val_accuracy: 0.8551
# Epoch 60/70
# 782/782 [==============================] - 16s 20ms/step - loss: 9.8393e-04 - accuracy: 0.9999 - val_loss: 0.6523 - val_accuracy: 0.8549
# Epoch 61/70
# 782/782 [==============================] - 16s 20ms/step - loss: 9.7657e-04 - accuracy: 1.0000 - val_loss: 0.6663 - val_accuracy: 0.8520
# Epoch 62/70
# 782/782 [==============================] - 16s 20ms/step - loss: 9.4642e-04 - accuracy: 1.0000 - val_loss: 0.6562 - val_accuracy: 0.8560
# Epoch 63/70
# 782/782 [==============================] - 16s 20ms/step - loss: 9.9410e-04 - accuracy: 1.0000 - val_loss: 0.6554 - val_accuracy: 0.8567
# Epoch 64/70
# 782/782 [==============================] - 16s 20ms/step - loss: 9.5793e-04 - accuracy: 0.9999 - val_loss: 0.6549 - val_accuracy: 0.8561
# Epoch 65/70
# 782/782 [==============================] - 16s 20ms/step - loss: 8.7383e-04 - accuracy: 1.0000 - val_loss: 0.6554 - val_accuracy: 0.8571
# Epoch 66/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.6555 - val_accuracy: 0.8563
# Epoch 67/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.6606 - val_accuracy: 0.8557
# Epoch 68/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.6574 - val_accuracy: 0.8561
# Epoch 69/70
# 782/782 [==============================] - 16s 20ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.6594 - val_accuracy: 0.8556
# Epoch 70/70
# 782/782 [==============================] - 16s 20ms/step - loss: 8.6975e-04 - accuracy: 1.0000 - val_loss: 0.6572 - val_accuracy: 0.8552
#
#  Test accuracy
#               precision    recall  f1-score   support
#
#            0     0.8472    0.8930    0.8695      1000
#            1     0.9434    0.9330    0.9382      1000
#            2     0.8042    0.7680    0.7857      1000
#            3     0.7543    0.7030    0.7277      1000
#            4     0.8118    0.8370    0.8242      1000
#            5     0.7879    0.7840    0.7860      1000
#            6     0.8691    0.9100    0.8891      1000
#            7     0.8953    0.8810    0.8881      1000
#            8     0.9222    0.9130    0.9176      1000
#            9     0.9091    0.9300    0.9194      1000
#
#     accuracy                         0.8552     10000
#    macro avg     0.8545    0.8552    0.8546     10000
# weighted avg     0.8545    0.8552    0.8546     10000

# %% [markdown]
# This results in 85% accuracy, which is pretty good, but it seems to be overfitting.
#
# ### GoogLeNet Experiment 2: Data Augmentation
#
# Let's see if data augmentation helps with the overfitting problem.

# %%
numberOfEpochs = 70
initialLearningRate = 0.005

def polynomial_decay(epoch):
    maxEpochs = numberOfEpochs
    baseLearningRate = initialLearningRate
    power = 1.0
    
    alpha = baseLearningRate * (1 - (epoch / float(numberOfEpochs))) ** power
    
    # return the learning rate
    return alpha
    
# load cifar10 data
((trainX, trainY), (testX, testY)) = cifar10.load_data()
trainX = trainX.astype('float')
testX = testX.astype('float')

# use mean subtraction
mean = np.mean(trainX, axis = 0)
trainX -= mean
testX -= mean

# convert labels to one-hot
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)

# construct the image generator for data augmentation
aug = ImageDataGenerator(width_shift_range = 0.1, height_shift_range = 0.1,
                         horizontal_flip = True, fill_mode="nearest")

callbacks = [LearningRateScheduler(polynomial_decay)]

print('[INFO] compiling model...')
opt = SGD(learning_rate = initialLearningRate, momentum=0.9)
model = MiniGoogLeNet.build(width = 32, height = 32, depth = 3, classes = 10)
model.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics=["accuracy"])

# train the network
print("[INFO] training network...")

H = model.fit(aug.flow(trainX, trainY, batch_size=64), validation_data=(testX, testY),
              steps_per_epoch=len(trainX) // 64, epochs=numberOfEpochs, callbacks = callbacks, verbose=1)

# print a model summary
# print(model.summary())

# print a classification report
print('\n Test accuracy')
predictedY = model.predict(testX)
predictedY = predictedY.argmax(axis=1)
testY = testY.argmax(axis=1)
print(classification_report(testY, predictedY, digits=4))

# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, numberOfEpochs), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, numberOfEpochs), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, numberOfEpochs), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, numberOfEpochs), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
# Out:
# [INFO] compiling model...
# [INFO] training network...
# Epoch 1/70
# 781/781 [==============================] - 18s 22ms/step - loss: 1.4982 - accuracy: 0.4532 - val_loss: 1.4011 - val_accuracy: 0.5273
# Epoch 2/70
# 781/781 [==============================] - 17s 21ms/step - loss: 1.0780 - accuracy: 0.6126 - val_loss: 1.3076 - val_accuracy: 0.5547
# Epoch 3/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.9063 - accuracy: 0.6819 - val_loss: 1.4028 - val_accuracy: 0.5718
# Epoch 4/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.7892 - accuracy: 0.7267 - val_loss: 0.8165 - val_accuracy: 0.7219
# Epoch 5/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.7073 - accuracy: 0.7558 - val_loss: 1.0414 - val_accuracy: 0.6750
# Epoch 6/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.6422 - accuracy: 0.7788 - val_loss: 0.8100 - val_accuracy: 0.7342
# Epoch 7/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.5952 - accuracy: 0.7966 - val_loss: 0.6505 - val_accuracy: 0.7762
# Epoch 8/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.5517 - accuracy: 0.8128 - val_loss: 0.6354 - val_accuracy: 0.7765
# Epoch 9/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.5178 - accuracy: 0.8227 - val_loss: 0.5767 - val_accuracy: 0.8030
# Epoch 10/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.4874 - accuracy: 0.8337 - val_loss: 0.7099 - val_accuracy: 0.7714
# Epoch 11/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.4589 - accuracy: 0.8426 - val_loss: 0.7052 - val_accuracy: 0.7750
# Epoch 12/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.4321 - accuracy: 0.8509 - val_loss: 0.5855 - val_accuracy: 0.8058
# Epoch 13/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.4160 - accuracy: 0.8581 - val_loss: 0.6920 - val_accuracy: 0.7864
# Epoch 14/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.3964 - accuracy: 0.8648 - val_loss: 0.5487 - val_accuracy: 0.8231
# Epoch 15/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.3753 - accuracy: 0.8722 - val_loss: 0.5747 - val_accuracy: 0.8130
# Epoch 16/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.3588 - accuracy: 0.8778 - val_loss: 0.6488 - val_accuracy: 0.7992
# Epoch 17/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.3380 - accuracy: 0.8852 - val_loss: 0.4788 - val_accuracy: 0.8384
# Epoch 18/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.3333 - accuracy: 0.8858 - val_loss: 0.5124 - val_accuracy: 0.8359
# Epoch 19/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.3133 - accuracy: 0.8916 - val_loss: 0.4856 - val_accuracy: 0.8390
# Epoch 20/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.2994 - accuracy: 0.8960 - val_loss: 0.4738 - val_accuracy: 0.8508
# Epoch 21/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.2875 - accuracy: 0.9012 - val_loss: 0.5054 - val_accuracy: 0.8447
# Epoch 22/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.2790 - accuracy: 0.9043 - val_loss: 0.4970 - val_accuracy: 0.8419
# Epoch 23/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.2693 - accuracy: 0.9058 - val_loss: 0.4299 - val_accuracy: 0.8688
# Epoch 24/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.2551 - accuracy: 0.9131 - val_loss: 0.4036 - val_accuracy: 0.8710
# Epoch 25/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.2493 - accuracy: 0.9153 - val_loss: 0.5081 - val_accuracy: 0.8520
# Epoch 26/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.2377 - accuracy: 0.9188 - val_loss: 0.3843 - val_accuracy: 0.8780
# Epoch 27/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.2293 - accuracy: 0.9202 - val_loss: 0.4189 - val_accuracy: 0.8698
# Epoch 28/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.2222 - accuracy: 0.9227 - val_loss: 0.4239 - val_accuracy: 0.8651
# Epoch 29/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.2134 - accuracy: 0.9265 - val_loss: 0.4287 - val_accuracy: 0.8687
# Epoch 30/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.2068 - accuracy: 0.9278 - val_loss: 0.5606 - val_accuracy: 0.8426
# Epoch 31/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.2007 - accuracy: 0.9305 - val_loss: 0.4718 - val_accuracy: 0.8624
# Epoch 32/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1886 - accuracy: 0.9345 - val_loss: 0.4949 - val_accuracy: 0.8556
# Epoch 33/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1787 - accuracy: 0.9392 - val_loss: 0.5114 - val_accuracy: 0.8522
# Epoch 34/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1787 - accuracy: 0.9391 - val_loss: 0.4213 - val_accuracy: 0.8794
# Epoch 35/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1724 - accuracy: 0.9396 - val_loss: 0.4706 - val_accuracy: 0.8649
# Epoch 36/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1649 - accuracy: 0.9436 - val_loss: 0.4174 - val_accuracy: 0.8804
# Epoch 37/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1572 - accuracy: 0.9457 - val_loss: 0.5004 - val_accuracy: 0.8597
# Epoch 38/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1532 - accuracy: 0.9466 - val_loss: 0.5250 - val_accuracy: 0.8507
# Epoch 39/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1461 - accuracy: 0.9488 - val_loss: 0.3914 - val_accuracy: 0.8873
# Epoch 40/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1416 - accuracy: 0.9512 - val_loss: 0.4236 - val_accuracy: 0.8839
# Epoch 41/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1366 - accuracy: 0.9544 - val_loss: 0.4347 - val_accuracy: 0.8742
# Epoch 42/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1295 - accuracy: 0.9558 - val_loss: 0.4077 - val_accuracy: 0.8840
# Epoch 43/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1236 - accuracy: 0.9572 - val_loss: 0.3853 - val_accuracy: 0.8919
# Epoch 44/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.1205 - accuracy: 0.9592 - val_loss: 0.3800 - val_accuracy: 0.8887
# Epoch 45/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1140 - accuracy: 0.9610 - val_loss: 0.4874 - val_accuracy: 0.8667
# Epoch 46/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1143 - accuracy: 0.9610 - val_loss: 0.4184 - val_accuracy: 0.8883
# Epoch 47/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1084 - accuracy: 0.9629 - val_loss: 0.4353 - val_accuracy: 0.8823
# Epoch 48/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1085 - accuracy: 0.9631 - val_loss: 0.4466 - val_accuracy: 0.8785
# Epoch 49/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.1006 - accuracy: 0.9655 - val_loss: 0.5252 - val_accuracy: 0.8626
# Epoch 50/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.0959 - accuracy: 0.9680 - val_loss: 0.4062 - val_accuracy: 0.8908
# Epoch 51/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.0938 - accuracy: 0.9678 - val_loss: 0.4121 - val_accuracy: 0.8843
# Epoch 52/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.0894 - accuracy: 0.9697 - val_loss: 0.4003 - val_accuracy: 0.8926
# Epoch 53/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.0848 - accuracy: 0.9715 - val_loss: 0.3879 - val_accuracy: 0.8954
# Epoch 54/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.0800 - accuracy: 0.9726 - val_loss: 0.3789 - val_accuracy: 0.8996
# Epoch 55/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.0799 - accuracy: 0.9736 - val_loss: 0.4151 - val_accuracy: 0.8911
# Epoch 56/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.0751 - accuracy: 0.9748 - val_loss: 0.3994 - val_accuracy: 0.8920
# Epoch 57/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.0758 - accuracy: 0.9750 - val_loss: 0.3957 - val_accuracy: 0.8939
# Epoch 58/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.0707 - accuracy: 0.9766 - val_loss: 0.3738 - val_accuracy: 0.9002
# Epoch 59/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.0694 - accuracy: 0.9778 - val_loss: 0.3835 - val_accuracy: 0.8960
# Epoch 60/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.0688 - accuracy: 0.9772 - val_loss: 0.4332 - val_accuracy: 0.8880
# Epoch 61/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.0640 - accuracy: 0.9796 - val_loss: 0.4043 - val_accuracy: 0.8949
# Epoch 62/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.0621 - accuracy: 0.9799 - val_loss: 0.3884 - val_accuracy: 0.8987
# Epoch 63/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.0564 - accuracy: 0.9819 - val_loss: 0.3823 - val_accuracy: 0.9002
# Epoch 64/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.0564 - accuracy: 0.9821 - val_loss: 0.4039 - val_accuracy: 0.8976
# Epoch 65/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.0548 - accuracy: 0.9824 - val_loss: 0.3705 - val_accuracy: 0.9036
# Epoch 66/70
# 781/781 [==============================] - 16s 21ms/step - loss: 0.0516 - accuracy: 0.9841 - val_loss: 0.3739 - val_accuracy: 0.9017
# Epoch 67/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.0532 - accuracy: 0.9834 - val_loss: 0.3696 - val_accuracy: 0.9028
# Epoch 68/70
# 781/781 [==============================] - 17s 22ms/step - loss: 0.0518 - accuracy: 0.9836 - val_loss: 0.3699 - val_accuracy: 0.9025
# Epoch 69/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.0490 - accuracy: 0.9851 - val_loss: 0.3685 - val_accuracy: 0.9018
# Epoch 70/70
# 781/781 [==============================] - 17s 21ms/step - loss: 0.0496 - accuracy: 0.9841 - val_loss: 0.3716 - val_accuracy: 0.9024
#
#  Test accuracy
#               precision    recall  f1-score   support
#
#            0     0.9019    0.9100    0.9059      1000
#            1     0.9350    0.9630    0.9488      1000
#            2     0.8737    0.8510    0.8622      1000
#            3     0.8238    0.8180    0.8209      1000
#            4     0.8893    0.9000    0.8946      1000
#            5     0.8775    0.8310    0.8536      1000
#            6     0.8937    0.9500    0.9210      1000
#            7     0.9323    0.9220    0.9271      1000
#            8     0.9554    0.9430    0.9492      1000
#            9     0.9398    0.9360    0.9379      1000
#
#     accuracy                         0.9024     10000
#    macro avg     0.9022    0.9024    0.9021     10000
# weighted avg     0.9022    0.9024    0.9021     10000

# %% [markdown]
# We've now cracked 90% for the first time with CIFAR-10!
